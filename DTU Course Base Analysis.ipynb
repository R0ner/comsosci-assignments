# %%
import json

with open("coursedic.json", "r") as f:
    data = json.load(f)

# %%
for k, v in data.items():
    print(k, v.get("name"))
# Out:
# 26124 Koordinationskemi (Uorganisk Kemi 2)
# 11341 Bærende konstruktioner 1
# 11911 Konstruktionselementer og deres virkemåde
# 11952 Bygnings Informations Modellering (BIM)
# 11951 BIM og visuel kommunikation
# 02327 Indledende databaser og database programmering
# 42282 Smarte byer
# 31321 Emner inden for avanceret regulering
# 12911 Introduktion til god videnskab inden for
# miljøteknologi
# 42750 Bæredygtighedsvurdering og kommunikation
# 02431 Risikomanagement
# 22107 Forskningsfordybelse, Life Science
# 22005 Videregående høreforskningsemner
# 42786 Journal Analysis
# 42785 Academic Writing
# 26245 Computerbaserede metoder i kemi og biologi
# 02964 Software Development - med fokus på Continuous Integration og
# Continuous Deployment
# 27455 Mikrobiel adaptation til industrielle processer
# 42b86 Sustainable Business Innovation
# 62381 Trafik- og transportplanlægning
# 28855 GMP og kvalitet i farmaceutisk, biotek og fødevareindustri -
# Teoretisk version
# ...

# %%
for k, v in data["01005"].items():
    print(k)
# Out:
# grades
# reviews
# name

# %%
for k in data["01005"]["grades"]:
    print(k)
# Out:
# {'12': '110', '10': '361', '7': '372', '4': '80', '02': '0', '00': '0', '-3': '0', 'Bestået': '0', 'Ikkebestået': '419', 'Syg': '6', 'Ejmødt': '76', 'timestamp': 'Summer-2021', 'participants': 1342, 'pass_percentage': 64, 'avg': 8.5, 'url': 'http://karakterer.dtu.dk/Histogram/1/01005/Summer-2021'}
# {'12': '145', '10': '320', '7': '273', '4': '62', '02': '4', '00': '0', '-3': '0', 'Bestået': '0', 'Ikkebestået': '192', 'Syg': '7', 'Ejmødt': '90', 'timestamp': 'Summer-2020', 'participants': 996, 'pass_percentage': 73, 'avg': 8.8, 'url': 'http://karakterer.dtu.dk/Histogram/1/01005/Summer-2020'}
# {'12': '107', '10': '245', '7': '351', '4': '89', '02': '0', '00': '0', '-3': '265', 'Bestået': '0', 'Ikkebestået': '13', 'Syg': '11', 'Ejmødt': '45', 'timestamp': 'Summer-2019', 'participants': 1070, 'pass_percentage': 70, 'avg': 5.4, 'url': 'http://karakterer.dtu.dk/Histogram/1/01005/Summer-2019'}
# ...
